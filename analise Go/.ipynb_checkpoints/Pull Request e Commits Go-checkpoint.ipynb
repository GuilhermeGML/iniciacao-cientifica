# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pr = pd.read_csv("pr_reviews_go.csv")
df_pr.columns = [
  "author_login",
  "author_association",
  "body",
  "submitted_at",
  "includes_created_edit",
  "state"
]
df_pr
# Out:
#       author_login author_association body          submitted_at  \
# 0           Zxilly        CONTRIBUTOR  NaN  2024-08-20T17:36:47Z
# 1     timothy-king        CONTRIBUTOR  NaN  2024-08-20T17:43:35Z
# 2       Sec32fun32               NONE  NaN  2024-08-02T19:27:43Z
# 3       Sec32fun32               NONE  NaN  2024-08-08T20:54:29Z
# 4       Sec32fun32               NONE  NaN  2024-07-18T17:28:00Z
# ..             ...                ...  ...                   ...
# 270  kirillDanshin               NONE  NaN  2018-03-31T21:22:50Z
# 271         majolo               NONE  NaN  2018-02-13T10:18:08Z
# 272         mewmew        CONTRIBUTOR  NaN  2018-03-29T23:10:43Z
# 273          bbuck               NONE  NaN  2021-09-14T22:16:58Z
# 274  amazingandyyy               NONE  NaN  2018-02-09T19:23:00Z
#
#      includes_created_edit      state
# 0                    False  COMMENTED
# 1                    False  COMMENTED
# 2                    False   APPROVED
# 3                    False   APPROVED
# 4                    False   APPROVED
# ..                     ...        ...
# 270                  False   APPROVED
# 271                  False   APPROVED
# 272                  False  COMMENTED
# 273                  False  COMMENTED
# 274                  False  COMMENTED
#
# [275 rows x 6 columns]

# %%
repositorio = 'https://github.com/golang/go.git'
df_commits = pd.read_csv("DF Commits Go.csv")
df_commits
# Out:
#                                            hash  \
# 0      7d7c6a97f815e9279d08cfaea7d5efb5e90695a8
# 1      0bb0b61d6a85b2a1a33dcbc418089656f2754d32
# 2      0744ac969119db8a0ad3253951d375eb77cfce9e
# 3      d82b11e4a46307f1f1415024f33263e819c222b8
# 4      18c5b488a3b2e218c0e0cf2a7d4820d9da93a554
# ...                                         ...
# 61176  c39bc22c141bc6990e4e2abf604dcf56669ff779
# 61177  89f29a772a519cbf352513b55356291a94e15ada
# 61178  5c1a68aedd09ba9992ca0b1c6d0a00d8e1ce8f8f
# 61179  cbdb3545ad7d15204ef15daf124393aefb7b2c3d
# 61180  70f4717e96cf9d8ca8a5f439d7d6487ec822ce49
#
#                                                  message       author_name  \
# 0      hello, world\n\nR=ken\nDELTA=7  (7 added, 0 de...   Brian Kernighan
# 1      convert to C\n\nR=dmr\nDELTA=6  (0 added, 3 de...   Brian Kernighan
# 2      convert to Draft-Proposed ANSI C\n\nR=dmr\nDEL...   Brian Kernighan
# 3      last-minute fix: convert to ANSI C\n\nR=dmr\nD...   Brian Kernighan
# 4                  Go spec starting point.\n\nSVN=111041  Robert Griesemer
# ...                                                  ...               ...
# 61176  all: wire up swisstable maps\n\nUse the new Sw...     Michael Pratt
# 61177  runtime: clarify work.bytesMarked documentatio...   Austin Clements
# 61178  internal/syscall/windows: fix handle leak in M...           qmuntal
# 61179  timer: fix Stop link in Timer.Reset doc commen...      Robert Pająk
# 61180  os: use relative paths in a test dir in TestOp...       Damien Neil
#
#                author_email                author_date    committer_name  \
# 0                       bwk  1972-07-18 19:05:45-05:00   Brian Kernighan
# 1                       bwk  1974-01-20 01:02:03-04:00   Brian Kernighan
# 2              research!bwk  1988-04-01 02:02:04-05:00   Brian Kernighan
# 3      bwk@research.att.com  1988-04-01 02:03:04-05:00   Brian Kernighan
# 4            gri@golang.org  2008-03-02 20:47:34-08:00  Robert Griesemer
# ...                     ...                        ...               ...
# 61176     mpratt@google.com  2024-05-03 13:03:04-04:00     Michael Pratt
# 61177     austin@google.com  2024-10-10 14:20:45-04:00      Gopher Robot
# 61178  quimmuntal@gmail.com  2024-10-14 21:32:40+02:00      Gopher Robot
# 61179  pellared@hotmail.com  2024-10-14 20:30:20+00:00      Gopher Robot
# 61180      dneil@google.com  2024-10-14 15:30:13-07:00       Damien Neil
#
#             committer_email             committer_date
# 0                       bwk  1972-07-18 19:05:45-05:00
# 1                       bwk  1974-01-20 01:02:03-04:00
# 2              research!bwk  1988-04-01 02:02:04-05:00
# 3      bwk@research.att.com  1988-04-01 02:03:04-05:00
# 4            gri@golang.org  2008-03-02 20:47:34-08:00
# ...                     ...                        ...
# 61176     mpratt@google.com  2024-10-14 19:58:47+00:00
# 61177      gobot@golang.org  2024-10-14 20:36:52+00:00
# 61178      gobot@golang.org  2024-10-14 20:58:52+00:00
# 61179      gobot@golang.org  2024-10-14 21:03:43+00:00
# 61180      dneil@google.com  2024-10-15 17:23:27+00:00
#
# [61181 rows x 8 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Converter a coluna de data de Pull Requests para datetime e configurar como índice
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr.set_index('submitted_at', inplace=True)

# Filtrar para datas a partir de 2005
df_pr = df_pr[df_pr.index.year > 2004]
monthly_pull_requests = df_pr.resample('M').size()

# Converter a coluna de data de Commits para datetime com timezone UTC e configurar como índice
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits.set_index('author_date', inplace=True)

# Filtrar para datas a partir de 2005
df_commits = df_commits[df_commits.index.year > 2004]
monthly_commits = df_commits.resample('M').size()

# Criar a figura para o gráfico sobreposto
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, color='blue', label='Pull Requests')

# Plotar Commits
sns.lineplot(x=monthly_commits.index, y=monthly_commits.values, color='green', label='Commits')

# Configurar título, rótulos e legenda
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo (A partir de 2005)')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits['year'] = df_commits['author_date'].dt.year

# Filtrar apenas anos a partir de 2004
df_commits = df_commits[df_commits['year'] >= 2004]

authors_commits_per_year = df_commits.groupby('year')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr['year'] = df_pr['submitted_at'].dt.year

# Filtrar apenas anos a partir de 2004
df_pr = df_pr[df_pr['year'] >= 2004]

authors_pr_per_year = df_pr.groupby('year')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_year.index, authors_commits_per_year.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_year.index, authors_pr_per_year.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Ano (Commits vs Pull Requests)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_commits_per_year.index)  # Exibir todos os anos
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
