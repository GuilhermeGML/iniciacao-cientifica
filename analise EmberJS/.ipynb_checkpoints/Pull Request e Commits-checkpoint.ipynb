# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pr = pd.read_csv("pr_reviews_EmberJS.csv")
df_pr.columns = [
  "author_login",
  "author_association",
  "body",
  "submitted_at",
  "includes_created_edit",
  "state"
]
df_pr
# Out:
#        author_login author_association body          submitted_at  \
# 0     NullVoxPopuli        CONTRIBUTOR  NaN  2024-10-06T12:46:44Z
# 1           Windvis        CONTRIBUTOR  NaN  2024-10-05T12:59:04Z
# 2           Windvis        CONTRIBUTOR  NaN  2024-10-05T13:27:13Z
# 3           Windvis        CONTRIBUTOR  NaN  2024-10-05T13:46:59Z
# 4           Windvis        CONTRIBUTOR  NaN  2024-10-06T13:25:48Z
# ...             ...                ...  ...                   ...
# 6280   stefanpenner             MEMBER  NaN  2017-05-09T17:42:09Z
# 6281        mixonic             MEMBER  NaN  2017-05-12T17:50:33Z
# 6282        rwjblue             MEMBER  NaN  2016-09-29T12:48:10Z
# 6283    chadhietala        CONTRIBUTOR  NaN  2016-09-29T15:18:08Z
# 6284   pixelhandler        CONTRIBUTOR  NaN  2016-11-18T19:39:48Z
#
#       includes_created_edit      state
# 0                     False   APPROVED
# 1                     False  COMMENTED
# 2                     False  COMMENTED
# 3                     False  COMMENTED
# 4                     False  COMMENTED
# ...                     ...        ...
# 6280                  False  COMMENTED
# 6281                  False  COMMENTED
# 6282                  False  COMMENTED
# 6283                  False  COMMENTED
# 6284                  False  COMMENTED
#
# [6285 rows x 6 columns]

# %%
repositorio = "https://github.com/emberjs/ember.js.git"
df_commits = pd.read_csv("DF Commits EmberJs.csv")
df_commits
# Out:
#                                            hash  \
# 0      24f801c64e57dad499a5659b2efcac363e6ade86
# 1      7aaccb4cf0abb7762b63fcffe93a1ad7286b7e48
# 2      07de0bf319a305d1f79a81b00000877c2397743a
# 3      077e05a1c74457e1021c3ce0cd430cfc970e70c9
# 4      6114278d3a86d24ad004971a6db5fa3c5e8d8ea1
# ...                                         ...
# 22642  f9f9099c066ebe305d4e385da0fcb2abe9928290
# 22643  1322efb1062397f49bf8bd3d698e19ef7aa6bc9d
# 22644  1fe50e876dbf537070ac41b864161613d8ddfab7
# 22645  e0cf04730a4cf4ce0bdd4c78be0da911436299f8
# 22646  0f9b3fcebb9d813f438a946f4b7d253e11311672
#
#                                                  message    author_name  \
# 0                                           first commit        tomhuda
# 1      Initial commit. Import runtime into SproutCore...        tomhuda
# 2      Remove the large SC.Error class and replace it...        tomhuda
# 3              Clean up and de-lint Array and Enumerable        tomhuda
# 4                                      de-lint Freezable        tomhuda
# ...                                                  ...            ...
# 22642  Add v5.12.0-beta.3 to CHANGELOG for `ember-sou...  Katie Gengler
# 22643  Add v5.11.1 to CHANGELOG for `ember-source`\n\...  Katie Gengler
# 22644  Add v5.12.0 to CHANGELOG for ember-source\n\n(...  Katie Gengler
# 22645  Add v6.0.0-beta.1 to CHANGELOG for `ember-sour...  Katie Gengler
# 22646                          Post-release version bump  Katie Gengler
#
#                  author_email                author_date committer_name  \
# 0      tomhuda@strobecorp.com  2011-04-30 13:24:11-07:00        tomhuda
# 1      tomhuda@strobecorp.com  2011-04-30 15:39:07-07:00        tomhuda
# 2      tomhuda@strobecorp.com  2011-04-30 22:23:23-07:00        tomhuda
# 3      tomhuda@strobecorp.com  2011-05-01 00:01:02-07:00        tomhuda
# 4      tomhuda@strobecorp.com  2011-05-01 00:04:10-07:00        tomhuda
# ...                       ...                        ...            ...
# 22642            katie@kmg.io  2024-09-23 14:36:34-04:00  Katie Gengler
# 22643            katie@kmg.io  2024-09-23 14:53:03-04:00  Katie Gengler
# 22644            katie@kmg.io  2024-09-30 14:07:54-04:00  Katie Gengler
# 22645            katie@kmg.io  2024-09-30 14:19:20-04:00  Katie Gengler
# 22646            katie@kmg.io  2024-09-30 14:21:41-04:00  Katie Gengler
#
#               committer_email             committer_date
# 0      tomhuda@strobecorp.com  2011-04-30 13:24:11-07:00
# 1      tomhuda@strobecorp.com  2011-04-30 21:05:01-07:00
# 2      tomhuda@strobecorp.com  2011-04-30 22:23:23-07:00
# 3      tomhuda@strobecorp.com  2011-05-01 00:01:02-07:00
# 4      tomhuda@strobecorp.com  2011-05-01 00:04:10-07:00
# ...                       ...                        ...
# 22642            katie@kmg.io  2024-09-23 14:43:59-04:00
# 22643            katie@kmg.io  2024-09-23 15:16:29-04:00
# 22644            katie@kmg.io  2024-09-30 14:12:19-04:00
# 22645            katie@kmg.io  2024-09-30 14:21:32-04:00
# 22646            katie@kmg.io  2024-09-30 14:21:41-04:00
#
# [22647 rows x 8 columns]

# %%
# Converter a coluna de data de Pull Requests para datetime e configurar como índice
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr.set_index('submitted_at', inplace=True)
monthly_pull_requests = df_pr.resample('M').size()

# Converter a coluna de data de Commits para datetime com timezone UTC e configurar como índice
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits.set_index('author_date', inplace=True)
monthly_commits = df_commits.resample('M').size()

# Criar a figura para o gráfico sobreposto
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, color='blue', label='Pull Requests')

# Plotar Commits
sns.lineplot(x=monthly_commits.index, y=monthly_commits.values, color='green', label='Commits')

# Configurar título, rótulos e legenda
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits['year'] = df_commits['author_date'].dt.year
authors_commits_per_year = df_commits.groupby('year')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr['year'] = df_pr['submitted_at'].dt.year
authors_pr_per_year = df_pr.groupby('year')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_year.index, authors_commits_per_year.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_year.index, authors_pr_per_year.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Ano (Commits vs Pull Requests)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_commits_per_year.index)  # Exibir todos os anos
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
