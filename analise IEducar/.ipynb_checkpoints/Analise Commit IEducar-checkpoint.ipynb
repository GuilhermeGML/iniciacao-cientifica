# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
repositorio = "https://github.com/ieducar/ieducar.git"

# %%
commits = []

for commit in Repository(repositorio).traverse_commits():
    record = {
        'hash': commit.hash,
        'message': commit.msg,
        'author_name': commit.author.name,
        'author_email': commit.author.email,
        'author_date': commit.author_date,
        'committer_name': commit.committer.name,
        'committer_email': commit.committer.email,
        'committer_date': commit.committer_date,
       
            }
    commits.append(record)

# Save it to FileCommits.csv
df_commits = pd.DataFrame(commits)

# %%
df_commits.to_csv('DF Commits IEducar.csv', index=False)

# %%
df_commits = pd.read_csv("DF Commits IEducar.csv")

# %%
df_commits
# Out:
#                                          hash  \
# 0    944789cbee4700dea7c6c1f3cd3f1af4d1aa9e4c
# 1    12eabe0ef6d2095001ee123763e9c89ca71083ca
# 2    4db404bf995bb95fa8772fdfda1a0269f0b01f24
# 3    579d24c5d8eb5b46f88b9dbb9febccf5594f49ce
# 4    7bda37b18818424c685c78c2bc4c2e370c38d42b
# ..                                        ...
# 747  222d15b3c679bc837accde8dac65aacd19d1e83d
# 748  36393ed4f203963fa587af4ceb1e9d17204bb0b6
# 749  8433623f78a6d240e1adf08b0ee395e48542c857
# 750  895a5a446db2c31f04b2aca323653387f7603530
# 751  4a61c8fbb7cfcdd559df359f9d2c7489814c48c0
#
#                                                message  \
# 0                                                  NaN
# 1                                                  NaN
# 2                               Teste do RepositÃ³rio.
# 3                                                  NaN
# 4        Adicionado cópia da licença GPLv2 (em inglês)
# ..                                                 ...
# 747                                   Removido comando
# 748  Merge pull request #25 from farribeiro/patch-1...
# 749  Atualiza o README\n\nDá uma data mais concreta...
# 750  Posterga a liberação do código\n\nVamos poster...
# 751                                   Update README.md
#
#                           author_name  \
# 0    pedro.simoes@planejamento.gov.br
# 1    pedro.simoes@planejamento.gov.br
# 2                 spb.lidia@gmail.com
# 3    pedro.simoes@planejamento.gov.br
# 4                Eriksen Costa Paixão
# ..                                ...
# 747           Fabio Rodrigues Ribeiro
# 748          Marcelo Griggio Cajueiro
# 749          Marcelo Griggio Cajueiro
# 750          Marcelo Griggio Cajueiro
# 751          Marcelo Griggio Cajueiro
#
#                                           author_email  \
# 0    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 1    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 2    spb.lidia@gmail.com@42592ce7-c759-0410-9932-bf...
# 3    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 4                       eriksen.paixao_bs@cobra.com.br
# ..                                                 ...
# 747                               farribeiro@gmail.com
# 748                          marcelocajueiro@gmail.com
# 749                          marcelocajueiro@gmail.com
# 750                          marcelocajueiro@gmail.com
# 751                          marcelocajueiro@gmail.com
#
#                    author_date                    committer_name  \
# 0    2009-03-11 15:17:09+00:00  pedro.simoes@planejamento.gov.br
# 1    2009-03-11 15:54:46+00:00  pedro.simoes@planejamento.gov.br
# 2    2009-03-30 13:58:14+00:00               spb.lidia@gmail.com
# 3    2009-04-02 17:48:11+00:00  pedro.simoes@planejamento.gov.br
# 4    2009-04-02 19:57:39+00:00              Eriksen Costa Paixão
# ..                         ...                               ...
# 747  2018-03-20 17:20:16-03:00           Fabio Rodrigues Ribeiro
# 748  2018-03-21 11:41:49-03:00                            GitHub
# 749  2018-04-17 11:05:55-03:00                            GitHub
# 750  2018-05-31 10:36:10-03:00                            GitHub
# 751  2018-06-10 15:26:26-03:00                            GitHub
#
#                                        committer_email  \
# 0    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 1    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 2    spb.lidia@gmail.com@42592ce7-c759-0410-9932-bf...
# 3    pedro.simoes@planejamento.gov.br@42592ce7-c759...
# 4                       eriksen.paixao_bs@cobra.com.br
# ..                                                 ...
# 747                               farribeiro@gmail.com
# 748                                 noreply@github.com
# 749                                 noreply@github.com
# 750                                 noreply@github.com
# 751                                 noreply@github.com
#
#                 committer_date
# 0    2009-03-11 15:17:09+00:00
# 1    2009-03-11 15:54:46+00:00
# 2    2009-03-30 13:58:14+00:00
# 3    2009-04-02 17:48:11+00:00
# 4    2009-04-02 19:57:39+00:00
# ..                         ...
# 747  2018-03-20 19:49:47-03:00
# 748  2018-03-21 11:41:49-03:00
# 749  2018-04-17 11:05:55-03:00
# 750  2018-05-31 10:36:10-03:00
# 751  2018-06-10 15:26:26-03:00
#
# [752 rows x 8 columns]

# %%
# Converter a coluna de data para datetime com timezone UTC
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)

# Remover linhas onde a conversão falhou (se houver)
df_commits = df_commits.dropna(subset=['author_date'])

# Definir a coluna de data como índice
df_commits.set_index('author_date', inplace=True)

# Agrupar por mês e contar o número de commits
monthly_pull_requests = df_commits.resample('M').size()

# Plotar o gráfico
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, marker='', color='blue')
plt.title('Número de Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Número de Commits')
plt.xticks(rotation=45)
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Converter a coluna 'author_date' para datetime com fuso horário UTC
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)

# Verificar se há valores nulos após a conversão
print(df_commits['author_date'].isnull().sum(), "valores inválidos em 'author_date'")

# Remover linhas com valores inválidos (opcional)
df_commits = df_commits.dropna(subset=['author_date'])

# Extrair o ano da coluna 'author_date'
df_commits['year'] = df_commits['author_date'].dt.year

# Contar o número de autores únicos por ano
authors_per_year = df_commits.groupby('year')['author_email'].nunique()

# Plotar o gráfico de linhas
plt.figure(figsize=(12, 6))
plt.plot(authors_per_year.index, authors_per_year.values, marker='', linestyle='-')
plt.title('Quantidade de Autores por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_per_year.index)  # Garantir que todos os anos sejam mostrados no eixo X
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
# Out:
# 0 valores inválidos em 'author_date'

# %%
# Converter a coluna 'committer_date' para datetime com fuso horário UTC
df_commits['committer_date'] = pd.to_datetime(df_commits['committer_date'], errors='coerce', utc=True)

# Verificar se há valores nulos após a conversão
print(df_commits['committer_date'].isnull().sum(), "valores inválidos em 'committer_date'")

# Remover linhas com valores inválidos (opcional)
df_commits = df_commits.dropna(subset=['committer_date'])

# Extrair o ano da coluna 'committer_date'
df_commits['year'] = df_commits['committer_date'].dt.year

# Contar o número de autores (committer_email) únicos por ano
authors_per_year = df_commits.groupby('year')['committer_email'].nunique()

# Plotar o gráfico de linhas
plt.figure(figsize=(12, 6))
plt.plot(authors_per_year.index, authors_per_year.values, marker='', linestyle='-')
plt.title('Quantidade de Commits por Ano (Autores Únicos)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_per_year.index)  # Garantir que todos os anos sejam mostrados no eixo X
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
# Out:
# 0 valores inválidos em 'committer_date'
