# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pr = pd.read_csv("pr_reviews_Puter.csv")
df_pr.columns = [
  "author_login",
  "author_association",
  "body",
  "submitted_at",
  "includes_created_edit",
  "state"
]
df_pr
# Out:
#       author_login author_association  \
# 0       decipher2k               NONE
# 1          Bbjj88h               NONE
# 2         AtkinsSJ       COLLABORATOR
# 3              NaN               NONE
# 4         AtkinsSJ       COLLABORATOR
# 5         AtkinsSJ       COLLABORATOR
# 6         AtkinsSJ       COLLABORATOR
# 7     KernelDeimos        CONTRIBUTOR
# 8     KernelDeimos        CONTRIBUTOR
# 9         AtkinsSJ       COLLABORATOR
# 10    KernelDeimos        CONTRIBUTOR
# 11    KernelDeimos        CONTRIBUTOR
# 12    KernelDeimos        CONTRIBUTOR
# 13        Braingix               NONE
# 14        Braingix               NONE
# 15    KernelDeimos        CONTRIBUTOR
# 16         shuguet        CONTRIBUTOR
# 17         shuguet        CONTRIBUTOR
# 18    KernelDeimos        CONTRIBUTOR
# 19    vineeth-vk11        CONTRIBUTOR
# 20         Choon38               NONE
# 21        AtkinsSJ       COLLABORATOR
# 22          jelveh        CONTRIBUTOR
# 23  SondreNjaastad        CONTRIBUTOR
# 24  SondreNjaastad        CONTRIBUTOR
# 25     mael-belval               NONE
# 26          jelveh        CONTRIBUTOR
# 27    KernelDeimos        CONTRIBUTOR
# 28         shuguet        CONTRIBUTOR
# 29        AtkinsSJ       COLLABORATOR
# 30        lsileoni        CONTRIBUTOR
# 31          jelveh        CONTRIBUTOR
# 32          jelveh        CONTRIBUTOR
# 33          jelveh        CONTRIBUTOR
# 34          jelveh        CONTRIBUTOR
# 35          jelveh        CONTRIBUTOR
# 36        AtkinsSJ       COLLABORATOR
# 37          jelveh        CONTRIBUTOR
# 38    vineeth-vk11        CONTRIBUTOR
# 39    vineeth-vk11        CONTRIBUTOR
# 40          jelveh        CONTRIBUTOR
# 41  devlopersabbir               NONE
# 42          jelveh        CONTRIBUTOR
#
#                                                  body          submitted_at  \
# 0                                                 NaN  2024-08-26T05:02:24Z
# 1                                                 NaN  2024-09-22T09:25:56Z
# 2                                    Thanks for this!  2024-05-19T10:52:05Z
# 3                             Stinky man has arrived!  2024-05-17T12:41:18Z
# 4                                                 NaN  2024-05-11T08:18:10Z
# 5                                          Thank you!  2024-05-10T08:31:24Z
# 6                                                 NaN  2024-05-13T15:23:30Z
# 7                                                 NaN  2024-05-08T16:15:02Z
# 8                                                 NaN  2024-04-22T23:27:35Z
# 9                                                 NaN  2024-04-06T10:49:28Z
# 10                                                NaN  2024-04-05T07:21:02Z
# 11                                                NaN  2024-04-04T20:11:51Z
# 12  The addition to `package.json` and missing imp...  2024-04-02T18:49:37Z
# 13                                                NaN  2024-04-02T19:08:02Z
# 14                                                NaN  2024-04-02T19:17:47Z
# 15                                                NaN  2024-03-31T20:20:01Z
# 16                                                NaN  2024-03-31T22:24:21Z
# 17                                                NaN  2024-04-01T00:09:48Z
# 18                                                NaN  2024-04-16T05:22:53Z
# 19                                                NaN  2024-03-22T19:17:20Z
# 20                                                NaN  2024-03-23T04:13:26Z
# 21  Hi, thank you for the translations!\n\nI spott...  2024-03-19T15:56:27Z
# 22                                                NaN  2024-03-19T02:49:56Z
# 23                                                NaN  2024-03-19T02:51:24Z
# 24                                                NaN  2024-03-19T02:52:01Z
# 25                                                NaN  2024-03-18T09:41:50Z
# 26  seems like when I re-arrange items an empty ar...  2024-03-16T18:37:16Z
# 27                                                NaN  2024-03-15T16:43:27Z
# 28                                                NaN  2024-03-15T22:48:50Z
# 29                   Generally seems good to me. :+1:  2024-03-11T11:00:38Z
# 30                                                NaN  2024-03-11T12:33:33Z
# 31                                                NaN  2024-03-11T17:16:59Z
# 32                                                NaN  2024-03-11T17:17:23Z
# 33                                                NaN  2024-03-11T17:28:55Z
# 34                                                NaN  2024-03-11T17:45:51Z
# 35                                                NaN  2024-03-11T18:28:40Z
# 36                                                NaN  2024-03-11T21:12:38Z
# 37                                                NaN  2024-03-11T21:14:04Z
# 38                                                NaN  2024-03-14T02:42:05Z
# 39                                                NaN  2024-03-14T02:44:58Z
# 40                                                NaN  2024-03-14T03:42:40Z
# 41                                                NaN  2024-03-12T08:49:15Z
# 42                                                NaN  2024-03-08T10:02:52Z
#
#     includes_created_edit              state
# 0                   False          COMMENTED
# 1                   False           APPROVED
# 2                   False           APPROVED
# 3                   False           APPROVED
# 4                   False  CHANGES_REQUESTED
# 5                   False           APPROVED
# 6                   False          COMMENTED
# 7                   False  CHANGES_REQUESTED
# 8                   False           APPROVED
# 9                   False          COMMENTED
# 10                  False           APPROVED
# 11                  False          COMMENTED
# 12                  False          COMMENTED
# 13                  False          COMMENTED
# 14                  False          COMMENTED
# 15                  False          COMMENTED
# 16                  False          COMMENTED
# 17                  False          COMMENTED
# 18                  False          COMMENTED
# 19                  False          COMMENTED
# 20                  False          COMMENTED
# 21                  False  CHANGES_REQUESTED
# 22                  False  CHANGES_REQUESTED
# 23                  False          COMMENTED
# 24                  False          COMMENTED
# 25                  False  CHANGES_REQUESTED
# 26                  False          COMMENTED
# 27                  False          COMMENTED
# 28                  False          COMMENTED
# 29                  False  CHANGES_REQUESTED
# 30                  False          COMMENTED
# 31                  False          COMMENTED
# 32                  False          COMMENTED
# 33                  False          COMMENTED
# 34                  False          COMMENTED
# 35                  False          COMMENTED
# 36                  False          COMMENTED
# 37                  False          COMMENTED
# 38                  False          COMMENTED
# 39                  False          COMMENTED
# 40                  False          COMMENTED
# 41                  False           APPROVED
# 42                  False           APPROVED

# %%
repositorio = "https://github.com/HeyPuter/puter.git"
df_commits = pd.read_csv("DF Commits Puter.csv")
df_commits
# Out:
#                                           hash  \
# 0     fa42b0871e3dde999d0c20dfd4e75d3ceb5eb649
# 1     c1adc1850942cc6afdc2d3062d490d3c65a68809
# 2     3b342e52dbb3b795b689b3e33f7ab07b87e807ae
# 3     17f0709a42cbaad86354a85a72dce7facc7ed81b
# 4     35a5eafd754369bf449915adea25a6905d29b38a
# ...                                        ...
# 1970  40f8634f243fdbeed75dedb525907dbf45587b87
# 1971  f9b9565dabea64dac5618cf2a4437c2bfd162037
# 1972  12a38b8258d600aec62f66622932e0e5d0ae07ce
# 1973  a8e843297ebaa814de1a3317fce67be551ac47a6
# 1974  a2216aaea2516f4468d3d04400f33c4cecd112f8
#
#                                                 message         author_name  \
# 0                                        Initial commit      Nariman Jelveh
# 1                                     Update .gitignore      Nariman Jelveh
# 2                                      Update README.md      Nariman Jelveh
# 3             Add license headers\n\nlame but necessary      Nariman Jelveh
# 4                                      Update README.md      Nariman Jelveh
# ...                                                 ...                 ...
# 1970                             Update bug_report.yaml             Zac0511
# 1971  Create test workflow\n\nbasic test workflow se...          Ibrahim H.
# 1972                             Show a badge on README          Ibrahim H.
# 1973                  Update README.te.md\n\nfixed typo  Surya Lohith Kotni
# 1974  Merge pull request #805 from lohitkotni/patch-...      Nariman Jelveh
#
#                                        author_email  \
# 0                                n.jelveh@gmail.com
# 1                                n.jelveh@gmail.com
# 2                                      nj@puter.com
# 3                                n.jelveh@gmail.com
# 4                                      nj@puter.com
# ...                                             ...
# 1970                      zac0511_le_vrai@proton.me
# 1971                              bitsnaps@yahoo.fr
# 1972                              bitsnaps@yahoo.fr
# 1973  110249804+lohitkotni@users.noreply.github.com
# 1974                                   nj@puter.com
#
#                     author_date  committer_name           committer_email  \
# 0     2024-03-02 18:39:14-08:00  Nariman Jelveh        n.jelveh@gmail.com
# 1     2024-03-02 18:55:45-08:00  Nariman Jelveh        n.jelveh@gmail.com
# 2     2024-03-02 19:45:36-08:00          GitHub        noreply@github.com
# 3     2024-03-02 19:59:32-08:00  Nariman Jelveh        n.jelveh@gmail.com
# 4     2024-03-02 23:24:15-08:00          GitHub        noreply@github.com
# ...                         ...             ...                       ...
# 1970  2024-10-12 10:15:53+02:00       Eric Dubé  eric.alex.dube@gmail.com
# 1971  2024-10-02 16:07:47+01:00       Eric Dubé  eric.alex.dube@gmail.com
# 1972  2024-10-02 16:10:01+01:00       Eric Dubé  eric.alex.dube@gmail.com
# 1973  2024-10-15 09:08:10+05:18          GitHub        noreply@github.com
# 1974  2024-10-14 20:53:37-07:00          GitHub        noreply@github.com
#
#                  committer_date
# 0     2024-03-02 18:39:14-08:00
# 1     2024-03-02 18:55:45-08:00
# 2     2024-03-02 19:45:36-08:00
# 3     2024-03-02 19:59:32-08:00
# 4     2024-03-02 23:24:15-08:00
# ...                         ...
# 1970  2024-10-14 22:16:04-04:00
# 1971  2024-10-14 22:18:36-04:00
# 1972  2024-10-14 22:18:36-04:00
# 1973  2024-10-15 09:08:10+05:18
# 1974  2024-10-14 20:53:37-07:00
#
# [1975 rows x 8 columns]

# %%
# Converter a coluna de data de Pull Requests para datetime e configurar como índice
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr.set_index('submitted_at', inplace=True)
monthly_pull_requests = df_pr.resample('M').size()

# Converter a coluna de data de Commits para datetime com timezone UTC e configurar como índice
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits.set_index('author_date', inplace=True)
monthly_commits = df_commits.resample('M').size()

# Criar a figura para o gráfico sobreposto
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, color='blue', label='Pull Requests')

# Plotar Commits
sns.lineplot(x=monthly_commits.index, y=monthly_commits.values, color='green', label='Commits')

# Configurar título, rótulos e legenda
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])

# Definir o índice como 'author_date' para fazer o resample por mês
df_commits.set_index('author_date', inplace=True)

# Contar o número de autores únicos por mês (commits)
authors_commits_per_month = df_commits.resample('M')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])

# Definir o índice como 'submitted_at' para fazer o resample por mês
df_pr.set_index('submitted_at', inplace=True)

# Contar o número de autores únicos por mês (pull requests)
authors_pr_per_month = df_pr.resample('M')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_month.index, authors_commits_per_month.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_month.index, authors_pr_per_month.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Mês (Commits vs Pull Requests)')
plt.xlabel('Mês')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(rotation=45)  # Para ajustar a rotação das datas
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
