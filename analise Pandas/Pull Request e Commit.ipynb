# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
    df_pr = pd.read_csv("pr_reviews_Pandas.csv")
    df_pr.columns = [
      "author_login",
      "author_association",
      "body",
      "submitted_at",
      "includes_created_edit",
      "state"
    ]
    df_pr
# Out:
#          author_login author_association body          submitted_at  \
# 0           mroeschke             MEMBER  NaN  2024-10-11T17:15:13Z
# 1            Wong2333        CONTRIBUTOR  NaN  2024-10-12T01:55:31Z
# 2           mroeschke             MEMBER  NaN  2024-10-12T03:14:21Z
# 3           mroeschke             MEMBER  NaN  2024-10-11T17:19:32Z
# 4           mroeschke             MEMBER  NaN  2024-10-09T19:04:53Z
# ...               ...                ...  ...                   ...
# 13169       lithomas1             MEMBER  NaN  2023-04-14T02:22:55Z
# 13170  datapythonista             MEMBER  NaN  2023-04-16T20:38:09Z
# 13171       lithomas1             MEMBER  NaN  2023-04-17T23:29:55Z
# 13172  datapythonista             MEMBER  NaN  2023-04-17T23:37:29Z
# 13173       lithomas1             MEMBER  NaN  2023-04-17T23:46:41Z
#
#        includes_created_edit      state
# 0                      False  COMMENTED
# 1                      False  COMMENTED
# 2                      False   APPROVED
# 3                      False   APPROVED
# 4                      False   APPROVED
# ...                      ...        ...
# 13169                  False  COMMENTED
# 13170                  False  COMMENTED
# 13171                  False  COMMENTED
# 13172                  False  COMMENTED
# 13173                  False  COMMENTED
#
# [13174 rows x 6 columns]

# %%
repositorio = "https://github.com/pandas-dev/pandas.git"
df_commits = pd.read_csv("DF Commits Pandas.csv")
df_commits
# Out:
#                                            hash  \
# 0      9d0080576446de475d34b0dbb58389b15cd4f529
# 1      ec1a0a2a2571dc2c1c26612b374d4a66b22f0938
# 2      1eeadf4e401647faa20911f531bc05c1872262ea
# 3      445114e1b20da8d4976c8d9050aa90c5bd508c54
# 4      c6b236db73ff81007909be6406f0e484edc4a9eb
# ...                                         ...
# 35601  4f328f08df90906198b3a3f955ab321018964f0a
# 35602  97c4ce390ae7dafb7f58a21184cc32d921edb6c6
# 35603  2b9ca0734ead966146321fa22d009d5eb186eb0b
# 35604  f1bdd0fa571e8689274c8dc7ba62ae503d74a568
# 35605  2a10e04a099d5f1633abcdfbb2dd9fdf09142f8d
#
#                                                  message  \
# 0      Initial directory structure.\n\ngit-svn-id: ht...
# 1      adding trunk\n\ngit-svn-id: http://pandas.goog...
# 2      oops\n\ngit-svn-id: http://pandas.googlecode.c...
# 3      added svn:ignore\n\ngit-svn-id: http://pandas....
# 4      first commit with cleaned up code\n\ngit-svn-i...
# ...                                                  ...
# 35601  TST (string dtype): resolve all infer_string T...
# 35602  Bump pypa/cibuildwheel from 2.20.0 to 2.21.0 (...
# 35603  STY: Bump pyright, pyupgrade and mypy for new ...
# 35604  DOC: Fix `GroupBy.ffill()` doc reference to ro...
# 35605  DOC: Fix title capitalization in documentation...
#
#                  author_name  \
# 0               Wes McKinney
# 1               Wes McKinney
# 2               Wes McKinney
# 3               Wes McKinney
# 4               Wes McKinney
# ...                      ...
# 35601  Joris Van den Bossche
# 35602        dependabot[bot]
# 35603       Matthew Roeschke
# 35604             Sparsh Sah
# 35605               Wong2333
#
#                                             author_email  \
# 0                                    wesmckinn@gmail.com
# 1                                    wesmckinn@gmail.com
# 2                                    wesmckinn@gmail.com
# 3                                    wesmckinn@gmail.com
# 4                                    wesmckinn@gmail.com
# ...                                                  ...
# 35601                       jorisvandenbossche@gmail.com
# 35602  49699333+dependabot[bot]@users.noreply.github.com
# 35603        10647082+mroeschke@users.noreply.github.com
# 35604                                sparshsah@gmail.com
# 35605                                  3201884732@qq.com
#
#                      author_date committer_name      committer_email  \
# 0      2009-07-31 15:07:16+00:00   Wes McKinney  wesmckinn@gmail.com
# 1      2009-08-05 02:32:49+00:00   Wes McKinney  wesmckinn@gmail.com
# 2      2009-08-05 02:33:13+00:00   Wes McKinney  wesmckinn@gmail.com
# 3      2009-08-05 03:17:29+00:00   Wes McKinney  wesmckinn@gmail.com
# 4      2009-08-05 03:30:16+00:00   Wes McKinney  wesmckinn@gmail.com
# ...                          ...            ...                  ...
# 35601  2024-10-10 15:19:55+02:00         GitHub   noreply@github.com
# 35602  2024-10-10 11:02:14-07:00         GitHub   noreply@github.com
# 35603  2024-10-10 12:15:00-10:00         GitHub   noreply@github.com
# 35604  2024-10-11 10:19:44-07:00         GitHub   noreply@github.com
# 35605  2024-10-12 11:14:27+08:00         GitHub   noreply@github.com
#
#                   committer_date
# 0      2009-07-31 15:07:16+00:00
# 1      2009-08-05 02:32:49+00:00
# 2      2009-08-05 02:33:13+00:00
# 3      2009-08-05 03:17:29+00:00
# 4      2009-08-05 03:30:16+00:00
# ...                          ...
# 35601  2024-10-10 15:19:55+02:00
# 35602  2024-10-10 11:02:14-07:00
# 35603  2024-10-10 15:15:00-07:00
# 35604  2024-10-11 10:19:44-07:00
# 35605  2024-10-11 20:14:27-07:00
#
# [35606 rows x 8 columns]

# %%
# Converter a coluna de data de Pull Requests para datetime e configurar como índice
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr.set_index('submitted_at', inplace=True)
monthly_pull_requests = df_pr.resample('M').size()

# Converter a coluna de data de Commits para datetime com timezone UTC e configurar como índice
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits.set_index('author_date', inplace=True)
monthly_commits = df_commits.resample('M').size()

# Criar a figura para o gráfico sobreposto
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, color='blue', label='Pull Requests')

# Plotar Commits
sns.lineplot(x=monthly_commits.index, y=monthly_commits.values, color='green', label='Commits')

# Configurar título, rótulos e legenda
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits['year'] = df_commits['author_date'].dt.year
authors_commits_per_year = df_commits.groupby('year')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr['year'] = df_pr['submitted_at'].dt.year
authors_pr_per_year = df_pr.groupby('year')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_year.index, authors_commits_per_year.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_year.index, authors_pr_per_year.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Ano (Commits vs Pull Requests)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_commits_per_year.index)  # Exibir todos os anos
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
