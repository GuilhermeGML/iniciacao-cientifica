# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pr = pd.read_csv("pr_reviews_dask.csv", delimiter=',')
df_pr.columns = [
  "author_login",
  "author_association",
  "body",
  "submitted_at",
  "includes_created_edit",
  "state"
]
df_pr
# Out:
#         author_login author_association                    body  \
# 0           rjzamora             MEMBER  Thanks @charlesbluca !
# 1              phofl       COLLABORATOR                     NaN
# 2         jrbourbeau             MEMBER          Thanks @phofl
# 3      hendrikmakait             MEMBER                     NaN
# 4              phofl       COLLABORATOR                     NaN
# ...              ...                ...                     ...
# 14553         jcrist             MEMBER                     NaN
# 14554  TomAugspurger             MEMBER                     NaN
# 14555       mrocklin             MEMBER                     NaN
# 14556         jcrist             MEMBER                     NaN
# 14557  TomAugspurger             MEMBER                     NaN
#
#                submitted_at  includes_created_edit      state
# 0      2024-08-23T20:42:06Z                  False   APPROVED
# 1      2024-08-21T13:22:08Z                  False   APPROVED
# 2      2024-08-21T13:16:55Z                  False  COMMENTED
# 3      2024-08-26T14:42:21Z                  False  COMMENTED
# 4      2024-08-26T18:44:07Z                  False  COMMENTED
# ...                     ...                    ...        ...
# 14553  2016-09-27T16:46:37Z                  False  COMMENTED
# 14554  2016-09-23T15:16:18Z                  False  COMMENTED
# 14555  2016-09-23T16:19:58Z                  False  COMMENTED
# 14556  2016-09-19T18:21:01Z                  False  COMMENTED
# 14557  2016-09-19T18:23:07Z                  False  COMMENTED
#
# [14558 rows x 6 columns]

# %%
repositorio = 'https://github.com/dask/dask.git'
df_commits = pd.read_csv("DF Commits Dask.csv")
df_commits
# Out:
#                                           hash  \
# 0     05488db498c1561d266c7b676b8a89021c03a9e7
# 1     3a2401080c77535ae8e997c775f957af877a846a
# 2     379f9c354d0c31175e3593dd56fb32a34c41d1a9
# 3     0fdd20304627607e53c561a7c34d205defa1c413
# 4     18463b0c7277240765d05ada1b9fb69364b1e128
# ...                                        ...
# 8291  984f24abdea8fdb1a6644270baa9df0d75dc3f1f
# 8292  2fbe18b29378f281f87341253c743f98f8e9ac72
# 8293  f8171f12f93b4bb47ef04945e20a6d6903e3b664
# 8294  72a14822139eedd140d928aa3b465706a04403f1
# 8295  6093009ccbd32311423219662525ea84b182d4be
#
#                                                 message  \
# 0                                       first commit -a
# 1                               accept args not in dict
# 2                              draft of array functions
# 3                            chunked transpose + 1 test
# 4                                clean up top docstring
# ...                                                 ...
# 8291  Update ``numpy`` and ``pyarrow`` versions in i...
# 8292     Increase visibility of GPU CI updates (#11345)
# 8293  Make rechunking in shuffle more intelligent to...
# 8294  Implement blockwise reshaping API for arrays (...
# 8295  Choose automatically between tasks-based and p...
#
#                 author_name                                    author_email  \
# 0           Matthew Rocklin                              mrocklin@gmail.com
# 1           Matthew Rocklin                              mrocklin@gmail.com
# 2           Matthew Rocklin                              mrocklin@gmail.com
# 3           Matthew Rocklin                              mrocklin@gmail.com
# 4           Matthew Rocklin                              mrocklin@gmail.com
# ...                     ...                                             ...
# 8291         James Bourbeau             jrbourbeau@users.noreply.github.com
# 8292  Charles Blackmon-Luca  20627856+charlesbluca@users.noreply.github.com
# 8293        Patrick Hoefler         61934744+phofl@users.noreply.github.com
# 8294        Patrick Hoefler         61934744+phofl@users.noreply.github.com
# 8295         Hendrik Makait                              hendrik@makait.com
#
#                     author_date   committer_name     committer_email  \
# 0     2014-12-21 13:26:20-08:00  Matthew Rocklin  mrocklin@gmail.com
# 1     2014-12-21 13:43:44-08:00  Matthew Rocklin  mrocklin@gmail.com
# 2     2014-12-23 11:00:24-08:00  Matthew Rocklin  mrocklin@gmail.com
# 3     2014-12-23 11:11:45-08:00  Matthew Rocklin  mrocklin@gmail.com
# 4     2014-12-23 11:16:44-08:00  Matthew Rocklin  mrocklin@gmail.com
# ...                         ...              ...                 ...
# 8291  2024-08-21 08:36:53-05:00           GitHub  noreply@github.com
# 8292  2024-08-23 16:42:15-04:00           GitHub  noreply@github.com
# 8293  2024-08-27 13:22:03+02:00           GitHub  noreply@github.com
# 8294  2024-08-27 19:41:06+02:00           GitHub  noreply@github.com
# 8295  2024-08-27 20:46:57+02:00           GitHub  noreply@github.com
#
#                  committer_date
# 0     2014-12-21 13:26:20-08:00
# 1     2014-12-21 13:43:44-08:00
# 2     2014-12-23 11:00:24-08:00
# 3     2014-12-23 11:11:45-08:00
# 4     2014-12-23 11:16:44-08:00
# ...                         ...
# 8291  2024-08-21 08:36:53-05:00
# 8292  2024-08-23 15:42:15-05:00
# 8293  2024-08-27 13:22:03+02:00
# 8294  2024-08-27 19:41:06+02:00
# 8295  2024-08-27 20:46:57+02:00
#
# [8296 rows x 8 columns]

# %%
# Converter a coluna 'submitted_at' para datetime
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'])

# Remover linhas onde a conversão falhou (se houver)
df_pr = df_pr.dropna(subset=['submitted_at'])

# Definir a coluna de data como índice
df_pr.set_index('submitted_at', inplace=True)

# Agrupar por mês e contar o número de pull requests
monthly_pull_requests = df_pr.resample('M').size()

# Inicializa listas para armazenar datas e contagem de commits
dates = []
commit_count = []

# Use o Repository para coletar os dados
for commit in Repository(repositorio).traverse_commits():
    dates.append(commit.committer_date.date())
    commit_count.append(1)  # Cada commit conta como 1

# Agrupe as datas e conte a quantidade de commits por data
date_counts = {}
for date in dates:
    if date in date_counts:
        date_counts[date] += 1
    else:
        date_counts[date] = 1

# Extraia as datas e contagens ordenadas
sorted_dates = sorted(date_counts.keys())
commit_counts = [date_counts[date] for date in sorted_dates]

# Plotar os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, marker='', color='blue', label='Pull Requests')

# Plotar Commits
plt.plot(sorted_dates, commit_counts, marker='', linestyle='-', color='green', label='Commits')

# Configurar título e rótulos
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits['year'] = df_commits['author_date'].dt.year
authors_commits_per_year = df_commits.groupby('year')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr['year'] = df_pr['submitted_at'].dt.year
authors_pr_per_year = df_pr.groupby('year')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_year.index, authors_commits_per_year.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_year.index, authors_pr_per_year.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Ano (Commits vs Pull Requests)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_commits_per_year.index)  # Exibir todos os anos
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
