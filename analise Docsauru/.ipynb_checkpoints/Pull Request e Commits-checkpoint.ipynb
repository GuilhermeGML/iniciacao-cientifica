# %%
from pydriller import Repository
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pr = pd.read_csv("pr_reviews_docusaurus.csv")
df_pr.columns = [
  "author_login",
  "author_association",
  "body",
  "submitted_at",
  "includes_created_edit",
  "state"
]
df_pr
# Out:
#      author_login author_association  \
# 0            zpao             MEMBER
# 1         slorber       COLLABORATOR
# 2       Josh-Cena       COLLABORATOR
# 3       Josh-Cena       COLLABORATOR
# 4       Josh-Cena       COLLABORATOR
# ...           ...                ...
# 6950    italicize        CONTRIBUTOR
# 6951     yangshun        CONTRIBUTOR
# 6952     yangshun        CONTRIBUTOR
# 6953     yangshun        CONTRIBUTOR
# 6954     yangshun        CONTRIBUTOR
#
#                                                    body          submitted_at  \
# 0     I should update some of these with new languag...  2024-10-08T18:13:25Z
# 1                                                   NaN  2024-10-09T07:14:21Z
# 2                                                   NaN  2024-10-02T21:15:16Z
# 3                                          :+1: Thanks!  2024-10-02T21:32:29Z
# 4                                                   NaN  2024-10-02T21:35:41Z
# ...                                                 ...                   ...
# 6950                                                NaN  2019-07-29T04:22:22Z
# 6951             Ah I see. That's a good catch. Thanks!  2019-08-04T19:42:48Z
# 6952  Thanks! Since most of your edits are small, in...  2019-07-27T22:03:32Z
# 6953                                            Thanks!  2019-07-27T02:13:01Z
# 6954                                            Thanks!  2019-07-26T18:07:32Z
#
#       includes_created_edit              state
# 0                     False           APPROVED
# 1                     False  CHANGES_REQUESTED
# 2                     False          COMMENTED
# 3                     False           APPROVED
# 4                     False          COMMENTED
# ...                     ...                ...
# 6950                  False          COMMENTED
# 6951                  False           APPROVED
# 6952                  False           APPROVED
# 6953                  False           APPROVED
# 6954                  False           APPROVED
#
# [6955 rows x 6 columns]

# %%
repositorio = "https://github.com/facebook/docusaurus.git"
df_commits = pd.read_csv("DF Commits Docusaurus.csv")
df_commits
# Out:
#                                           hash  \
# 0     e3139eea2f8e59ffa9566ae8e9438500f9fbdfa1
# 1     fe7d386f6711ceee5cf91e438fc066b93c6202a9
# 2     d620f2e6dd004e092106739046585f1e95af563e
# 3     6e1d5579fc778e6c25f1c01bd745792ab74d4b37
# 4     dbbfecaf6283d0e1d82eeccc2ecbe31bacf39f8d
# ...                                        ...
# 6098  5400690108ccaa63de008fd37776f1b7558d4e77
# 6099  c7fd8d17028212c3858fbd227f4316cf341dacae
# 6100  74c09aee3564e96a9b11e4022f60f3c0ef305d6f
# 6101  97e6c420998891dceaa492b7f252eb7ed11c1aa2
# 6102  904b53b9635699248aff22a897f637c4458c1595
#
#                                                 message       author_name  \
# 0                                        Initial commit       Joel Marcey
# 1     Add translation babel plugins and module to ge...          Frank Li
# 2     Use babylon and babel-traverse directly to fin...          Frank Li
# 3     Merge branch 'deltice' of https://github.com/f...          Frank Li
# 4                            Remove find-strings-plugin          Frank Li
# ...                                                 ...               ...
# 6098  docs: rename Facebook to Meta in GitHub-relate...            Raghav
# 6099  fix(core): move @docusaurus/faster to bundler ...  Sébastien Lorber
# 6100  feat(core): Replace Webpack with Rspack - `sit...  Sébastien Lorber
# 6101  refactor(core): remove useless Webpack wait pl...  Sébastien Lorber
# 6102  fix(core): fix handling of Swc html minifier w...  Sébastien Lorber
#
#                           author_email                author_date  \
# 0                         joelm@fb.com  2017-07-07 10:28:29-07:00
# 1                      frankli1@fb.com  2017-07-07 15:18:52-07:00
# 2                      frankli1@fb.com  2017-07-07 18:15:06-07:00
# 3                      frankli1@fb.com  2017-07-07 18:27:52-07:00
# 4                      frankli1@fb.com  2017-07-07 18:34:09-07:00
# ...                                ...                        ...
# 6098       raghavawasthi2005@gmail.com  2024-10-09 08:17:53+01:00
# 6099  slorber@users.noreply.github.com  2024-10-10 17:14:14+02:00
# 6100  slorber@users.noreply.github.com  2024-10-11 10:50:24+02:00
# 6101  slorber@users.noreply.github.com  2024-10-11 16:02:42+02:00
# 6102  slorber@users.noreply.github.com  2024-10-13 09:57:59+02:00
#
#      committer_name     committer_email             committer_date
# 0       Joel Marcey        joelm@fb.com  2017-07-07 10:28:29-07:00
# 1          Frank Li     frankli1@fb.com  2017-07-07 15:18:52-07:00
# 2          Frank Li     frankli1@fb.com  2017-07-07 18:15:06-07:00
# 3          Frank Li     frankli1@fb.com  2017-07-07 18:27:52-07:00
# 4          Frank Li     frankli1@fb.com  2017-07-07 18:34:09-07:00
# ...             ...                 ...                        ...
# 6098         GitHub  noreply@github.com  2024-10-09 09:17:53+02:00
# 6099         GitHub  noreply@github.com  2024-10-10 17:14:14+02:00
# 6100         GitHub  noreply@github.com  2024-10-11 10:50:24+02:00
# 6101         GitHub  noreply@github.com  2024-10-11 16:02:42+02:00
# 6102         GitHub  noreply@github.com  2024-10-13 09:57:59+02:00
#
# [6103 rows x 8 columns]

# %%
# Converter a coluna de data de Pull Requests para datetime e configurar como índice
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr.set_index('submitted_at', inplace=True)
monthly_pull_requests = df_pr.resample('M').size()

# Converter a coluna de data de Commits para datetime com timezone UTC e configurar como índice
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits.set_index('author_date', inplace=True)
monthly_commits = df_commits.resample('M').size()

# Criar a figura para o gráfico sobreposto
plt.figure(figsize=(12, 6))

# Plotar Pull Requests
sns.lineplot(x=monthly_pull_requests.index, y=monthly_pull_requests.values, color='blue', label='Pull Requests')

# Plotar Commits
sns.lineplot(x=monthly_commits.index, y=monthly_commits.values, color='green', label='Commits')

# Configurar título, rótulos e legenda
plt.title('Evolução de Pull Requests e Commits ao Longo do Tempo')
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.legend()  # Exibe a legenda para diferenciar as linhas

# Ajustar layout e exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Conversão de datas e contagem de autores (commits)
df_commits['author_date'] = pd.to_datetime(df_commits['author_date'], errors='coerce', utc=True)
df_commits = df_commits.dropna(subset=['author_date'])
df_commits['year'] = df_commits['author_date'].dt.year
authors_commits_per_year = df_commits.groupby('year')['author_email'].nunique()

# Conversão de datas e contagem de autores (pull requests)
df_pr['submitted_at'] = pd.to_datetime(df_pr['submitted_at'], errors='coerce')
df_pr = df_pr.dropna(subset=['submitted_at'])
df_pr['year'] = df_pr['submitted_at'].dt.year
authors_pr_per_year = df_pr.groupby('year')['author_login'].nunique()

# Plotando os dois gráficos juntos
plt.figure(figsize=(12, 6))

# Gráfico para os commits
plt.plot(authors_commits_per_year.index, authors_commits_per_year.values, label='Commits', color='blue', marker='', linestyle='-')

# Gráfico para os pull requests
plt.plot(authors_pr_per_year.index, authors_pr_per_year.values, label='Pull Requests', color='green', marker='', linestyle='-')

# Configurações do gráfico
plt.title('Quantidade de Autores Únicos por Ano (Commits vs Pull Requests)')
plt.xlabel('Ano')
plt.ylabel('Quantidade de Autores Únicos')
plt.xticks(authors_commits_per_year.index)  # Exibir todos os anos
plt.legend()  # Mostrar a legenda para diferenciar as linhas
plt.grid(False)
plt.tight_layout()

# Exibir o gráfico
plt.show()
